# %%
import Pkg; Pkg.activate(".")
# Out:
#   Activating project at `~/Documents/Projet_Informatique_Scientifique`

# %%
import Pkg; Pkg.add("DataStructures")
# Out:
#    Resolving package versions...
#      Project No packages added to or removed from `~/Documents/Projet_Informatique_Scientifique/Project.toml`
#     Manifest No packages added to or removed from `~/Documents/Projet_Informatique_Scientifique/Manifest.toml`

# %%
eltype(true)
# Out:
# Bool

# %%
function read_map(filename)
    map = nothing
    lines = 0
    height = 0
    width = 0

    open(filename) do f
        reading_map = false
        for raw_line in eachline(f)
            s = strip(raw_line)
            if startswith(s, "height")
                height = parse(Int, split(s)[2])
            elseif startswith(s, "width")
                width = parse(Int, split(s)[2])
            elseif startswith(s, "map")
                map = zeros(Float64, height, width)
                reading_map = true
                lines = 1 
            elseif reading_map && !isempty(s)
                for (i, c) in enumerate(s)
                    val = if c=='@' || c=='T'
                        Inf
                    elseif c=='.'
                        1
                    elseif c=='s'
                        5
                    elseif c=='w'
                        8
                    else
                        1
                    end
                    map[lines, i] = val
                end
                lines += 1
            end
        end
    end

    if map === nothing
        error("La map n'a jamais été initialisée ! Vérifie le fichier.")
    end

    return map
end
# Out:
# read_map (generic function with 1 method)

# %%
m=read_map("ht_store.map")
# Out:
# 37×37 Matrix{Float64}:
#  Inf  Inf  Inf  Inf   Inf   Inf   Inf   …  Inf  Inf  Inf  Inf  Inf  Inf  Inf
#  Inf  Inf  Inf  Inf   Inf   Inf   Inf      Inf  Inf  Inf  Inf  Inf  Inf  Inf
#  Inf  Inf  Inf  Inf   Inf   Inf   Inf      Inf  Inf  Inf  Inf  Inf  Inf  Inf
#  Inf  Inf  Inf   1.0   1.0   1.0   1.0     Inf  Inf  Inf  Inf  Inf  Inf  Inf
#  Inf  Inf  Inf   1.0   1.0   1.0   1.0     Inf  Inf  Inf  Inf  Inf  Inf  Inf
#  Inf  Inf  Inf   1.0   1.0   1.0   1.0  …  Inf  Inf  Inf  Inf  Inf  Inf  Inf
#  Inf  Inf  Inf   1.0   1.0   1.0   1.0     Inf  Inf  Inf  Inf  Inf  Inf  Inf
#  Inf  Inf  Inf   1.0   1.0   1.0   1.0     Inf  Inf  Inf  Inf  Inf  Inf  Inf
#  Inf  Inf  Inf   1.0   1.0   1.0   1.0     Inf  Inf  Inf  Inf  Inf  Inf  Inf
#  Inf  Inf  Inf  Inf   Inf    1.0   1.0     Inf  Inf  Inf  Inf  Inf  Inf  Inf
#  Inf  Inf  Inf  Inf   Inf    1.0   1.0  …  Inf  Inf  Inf  Inf  Inf  Inf  Inf
#  Inf  Inf  Inf   1.0   1.0   1.0   1.0     Inf  Inf  Inf  Inf  Inf  Inf  Inf
#  Inf  Inf  Inf   1.0   1.0   1.0   1.0     Inf  Inf  Inf  Inf  Inf  Inf  Inf
#   ⋮                          ⋮          ⋱   ⋮                        ⋮
#  Inf  Inf  Inf  Inf   Inf    1.0   1.0  …  Inf  Inf  Inf  Inf  Inf  Inf  Inf
#  Inf  Inf  Inf  Inf   Inf    1.0   1.0     Inf  Inf  Inf  Inf  Inf  Inf  Inf
#  Inf  Inf  Inf   1.0   1.0   1.0   1.0     Inf  Inf  Inf  Inf  Inf  Inf  Inf
#  Inf  Inf  Inf   1.0   1.0   1.0   1.0     Inf  Inf  Inf  Inf  Inf  Inf  Inf
#  Inf  Inf  Inf   1.0   1.0   1.0   1.0     Inf  Inf  Inf  Inf  Inf  Inf  Inf
#  Inf  Inf  Inf  Inf   Inf    1.0   1.0  …  Inf  Inf  Inf  Inf  Inf  Inf  Inf
#  Inf  Inf  Inf  Inf   Inf   Inf   Inf      Inf  Inf  Inf  Inf  Inf  Inf  Inf
#  Inf  Inf  Inf  Inf   Inf   Inf   Inf      Inf  Inf  Inf  Inf  Inf  Inf  Inf
#  Inf  Inf  Inf  Inf   Inf   Inf   Inf      Inf  Inf  Inf  Inf  Inf  Inf  Inf
#  Inf  Inf  Inf  Inf   Inf   Inf   Inf      Inf  Inf  Inf  Inf  Inf  Inf  Inf
#  Inf  Inf  Inf  Inf   Inf   Inf   Inf   …  Inf  Inf  Inf  Inf  Inf  Inf  Inf
#  Inf  Inf  Inf  Inf   Inf   Inf   Inf      Inf  Inf  Inf  Inf  Inf  Inf  Inf

# %%
function successeurs(y::Int, x::Int, height::Int, width::Int)
    voisins = []

    # déplacements possibles : haut, bas, gauche, droite
    deltas = [(0, -1), (0, 1), (-1, 0), (1, 0)]

    for (dy, dx) in deltas
        ny, nx = y + dy, x + dx
        if 1 <= ny <= height && 1 <= nx <= width
            push!(voisins, (ny, nx))
        end
    end
    return voisins
end
# Out:
# successeurs (generic function with 1 method)

# %%
successeurs(2,1,3,3)
# Out:
# 3-element Vector{Any}:
#  (2, 2)
#  (1, 1)
#  (3, 1)

# %%
function reconstruct_path(path, D::Tuple{Int,Int}, A::Tuple{Int,Int})
    node = A
    chemin = Tuple{Int,Int}[]
    if path[A...] == (-1,-1)
        return chemin
    end
    while node != D
        pushfirst!(chemin, node)
        node = path[node...]
    end
    pushfirst!(chemin, D)
    return chemin
end
# Out:
# reconstruct_path (generic function with 1 method)

# %%
using DataStructures

function algoBfs(fname::String, D::Tuple{Int, Int}, A::Tuple{Int, Int})
    m = read_map(fname)
    height, width = size(m)

    q = Queue{Tuple{Int,Int}}()
    enqueue!(q, D)

    dist = fill(-1, height, width)          # distances initialisées à -1
    dist[D...] = 0                          # distance de départ
    parent = Matrix{Union{Nothing, Tuple{Int,Int}}}(undef, height, width)
    parent .= nothing

    nb_etats = 0

    while !isempty(q)
        y, x = dequeue!(q)
        nb_etats += 1

        if (y, x) == A
            break
        end

        for (ny, nx) in successeurs(y, x, height, width)
            if dist[ny, nx] == -1 && isfinite(m[ny, nx])
                dist[ny, nx] = dist[y, x] + 1
                enqueue!(q, (ny, nx))
                parent[ny, nx] = (y, x)
            end
        end
    end

    function reconstruct_path(parent, D::Tuple{Int,Int}, A::Tuple{Int,Int})
        chemin = Tuple{Int,Int}[]
        node = A

        if parent[A...] === nothing
            return chemin
        end

        while node != D
            pushfirst!(chemin, node)
            node = parent[node...]
            if node === nothing
                return Tuple{Int,Int}[]
            end
        end

        pushfirst!(chemin, D)
        return chemin
    end

    path = reconstruct_path(parent, D, A)
    return dist[A...], nb_etats, path
end
# Out:
# algoBfs (generic function with 1 method)

# %%
dist, nb_etats, path=algoBfs("ht_store.map",(4,3),(5,5))
# Out:
# (3, 6, [(4, 3), (4, 4), (4, 5), (5, 5)])

# %%
dist,nb_etats, path = algoBfs("ht_store.map", (14,13), (24,13))
@time algoBfs("ht_store.map", (14,13), (24,13))
# Out:
# cannot convert a value to nothing for assignment
#
# Stacktrace:
#  [1] error(s::String)
#    @ Base ./error.jl:44
#  [2] nonnothingtype_checked(T::Type)
#    @ Base ./some.jl:32
#  [3] convert(::Type{Nothing}, x::Tuple{Int64, Int64})
#    @ Base ./some.jl:37
#  [4] setindex!
#    @ ./array.jl:996 [inlined]
#  [5] algoBfs(fname::String, D::Tuple{Int64, Int64}, A::Tuple{Int64, Int64})
#    @ Main ./In[146]:33
#  [6] top-level scope
#    @ In[148]:1
#  [7] eval(m::Module, e::Any)
#    @ Core ./boot.jl:489

# %%
function algoDijkstra(fname::String, D::Tuple{Int,Int}, A::Tuple{Int,Int})
    m = read_map(fname) 
    height, width = size(m)
    dist = fill(Inf, height, width)
    visited = fill(false, height, width)
    path = fill((-1,-1), height, width)
    pq = PriorityQueue{Tuple{Int,Int}, Float64}()
    nb_etats = 0
    function add(o::Tuple{Int,Int}, v::Tuple{Int,Int}, d::Float64)
        dist[v...] = d
        pq[v] = d
        path[v...] = o
    end
    add(D, D, 0.0)
    while !isempty(pq)
        v = dequeue!(pq)
        if !visited[v...]
            visited[v...] = true
            nb_etats += 1
            if v == A
                break
            end  
            for w in successeurs(v[1], v[2], height, width)
                d = dist[v...] + m[w...]
                if d < dist[w...]
                    add(v, w, d)
                end
            end
        end
    end
    
    return dist,nb_etats, reconstruct_path(path,D,A)
end
# Out:
# algoDijkstra (generic function with 1 method)

# %%
dist,nb_etats, path = algoDijkstra("ht_store.map", (4,3), (5,5))
println("Distance minimale : ", dist[5,5])
println("Chemin : ",path)
# Out:
# Distance minimale : 3.0
# Chemin : [(4, 3), (4, 4), (4, 5), (5, 5)]

# %%
m=read_map("simple.map")
println(m[2,3])
size(m)
# Out:
# Inf
# (5, 5)

# %%
println(m[3,2])
# Out:
# 1.0

# %%
println(m[2,4
        ])
# Out:
# 1.0

# %%
dist,nb_etats, path = algoDijkstra("simple.map", (1,2), (5,5))
chemin = reconstruct_path(path, (1,2),(5,5))
println("Distance minimale : ", dist[5,5])
println("Chemin : ", chemin)
# Out:
# Distance minimale : 7.0
# Chemin : [(1, 2), (2, 2), (3, 2), (3, 3), (3, 4), (3, 5), (4, 5), (5, 5)]

# %%
dist,nb_etats, path = algoDijkstra("ht_store.map", (14,13), (24,13))
@time algoDijkstra("ht_store.map", (14,13), (24,13))
chemin = reconstruct_path(path, (14,13), (24,13))
println("Distance minimale : ", dist[24,13])
println("Chemin : ", chemin)
# Out:
#   0.000271 seconds (8.52 k allocations: 262.898 KiB)
# Distance minimale : 12.0
# Chemin : [(14, 13), (14, 12), (15, 12), (16, 12), (17, 12), (18, 12), (19, 12), (20, 12), (21, 12), (22, 12), (23, 12), (23, 13), (24, 13)]

# %%
m=read_map("ht_store.map")
println(m[24,13])
# Out:
# 1.0

# %%
function algoGlouton(fname::String,D::Tuple{Int64, Int64},A::Tuple{Int64, Int64})
    function heuristic(v::Tuple{Int64, Int64},A::Tuple{Int64, Int64})
        vy,vx=v
        Ay,Ax=A
        return abs(vy-Ay)+abs(vx-Ax)    
    end
    m = read_map(fname) 
    height, width = size(m)
    dist = fill(Inf, height, width)
    visited = fill(false, height, width)
    path = fill((-1,-1), height, width)
    pq = PriorityQueue{Tuple{Int,Int}, Float64}()
    nb_etats = 0
    function add(o::Tuple{Int,Int}, v::Tuple{Int,Int}, d::Float64)
        dist[v...] = d
        pq[v] = heuristic(v,A)
        path[v...] = o
    end
    add(D, D, 0.0)
    while !isempty(pq)
        v = dequeue!(pq)
        if !visited[v...]
            visited[v...] = true
            nb_etats += 1
            if v == A
                break
            end  
            for w in successeurs(v[1], v[2], height, width)
                d = dist[v...] + m[w...]
                if d < dist[w...]
                    add(v, w, d)
                end
            end
        end
    end
    
    return dist,nb_etats,reconstruct_path(path,D,A)
end
# Out:
# algoGlouton (generic function with 1 method)

# %%
dist,nb_etats, path = algoGlouton("ht_store.map", (14,13), (24,13))
@time algoGlouton("ht_store.map", (14,13), (24,13))
println("Distance minimale : ", dist[24,13])
println("Chemin : ", path)
# Out:
#   0.000108 seconds (1.35 k allocations: 75.227 KiB)
# Distance minimale : 12.0
# Chemin : [(14, 13), (14, 12), (15, 12), (16, 12), (17, 12), (18, 12), (19, 12), (20, 12), (21, 12), (22, 12), (23, 12), (23, 13), (24, 13)]

# %%
function algoAstar(fname::String,D::Tuple{Int64, Int64},A::Tuple{Int64, Int64})
    function heuristic(v::Tuple{Int64, Int64},A::Tuple{Int64, Int64})
        vy,vx=v
        Ay,Ax=A
        return abs(vy-Ay)+abs(vx-Ax)    
    end
    m = read_map(fname) 
    height, width = size(m)
    dist = fill(Inf, height, width)
    visited = fill(false, height, width)
    path = fill((-1,-1), height, width)
    pq = PriorityQueue{Tuple{Int,Int}, Float64}()
    nb_etats = 0
    function add(o::Tuple{Int,Int}, v::Tuple{Int,Int}, d::Float64)
        dist[v...] = d
        pq[v] = d + heuristic(v,A)
        path[v...] = o
    end
    add(D, D, 0.0)
    while !isempty(pq)
        v = dequeue!(pq)
        if !visited[v...]
            visited[v...] = true
            nb_etats += 1
            if v == A
                break
            end  
            for w in successeurs(v[1], v[2], height, width)
                d = dist[v...] + m[w...]
                if d < dist[w...]
                    add(v, w, d)
                end
            end
        end
    end
    
    return dist,nb_etats,reconstruct_path(path,D,A)
end
# Out:
# algoAstar (generic function with 1 method)

# %%
dist,nb_etats, path = algoAstar("ht_store.map", (14,13), (24,13))
@time algoAstar("ht_store.map", (14,13), (24,13))
println("Distance minimale : ", dist[24,13])
println("Activité : ", nb_etats)
println("Chemin : ", path)
# Out:
#   0.000103 seconds (1.45 k allocations: 78.836 KiB)
# Distance minimale : 12.0
# Activité : 16
# Chemin : [(14, 13), (14, 12), (15, 12), (16, 12), (17, 12), (18, 12), (19, 12), (20, 12), (21, 12), (22, 12), (23, 12), (23, 13), (24, 13)]

# %% [markdown]
# **Benchmark**

# %%
m=read_map("brc101d.map")
println(m[279,1])
# Out:
# 1.0

# %%
println(m[476,25])
# Out:
# 1.0

# %%
dist,nb_etats, path = algoBfs("brc101d.map", (279,1), (476,25))
@time algoBfs("brc101d.map", (279,1), (476,25))
println("Distance : ", dist)
println("Activité : ", nb_etats)
println("Chemin : ", path)
# Out:
#   0.024265 seconds (579.22 k allocations: 23.189 MiB, 33.26% gc time)
# Distance : 457
# Activité : 18813
# Chemin : [(279, 1), (279, 2), (279, 3), (279, 4), (279, 5), (279, 6), (279, 7), (279, 8), (279, 9), (279, 10), (279, 11), (279, 12), (279, 13), (279, 14), (279, 15), (279, 16), (279, 17), (279, 18), (279, 19), (279, 20), (279, 21), (279, 22), (279, 23), (279, 24), (279, 25), (279, 26), (279, 27), (279, 28), (279, 29), (279, 30), (279, 31), (280, 31), (280, 32), (281, 32), (281, 33), (281, 34), (281, 35), (281, 36), (282, 36), (282, 37), (282, 38), (282, 39), (282, 40), (282, 41), (283, 41), (284, 41), (285, 41), (286, 41), (286, 42), (286, 43), (286, 44), (286, 45), (286, 46), (286, 47), (286, 48), (286, 49), (286, 50), (286, 51), (286, 52), (286, 53), (286, 54), (286, 55), (286, 56), (286, 57), (286, 58), (286, 59), (286, 60), (286, 61), (286, 62), (286, 63), (286, 64), (286, 65), (286, 66), (286, 67), (286, 68), (286, 69), (286, 70), (286, 71), (286, 72), (286, 73), (286, 74), (286, 75), (286, 76), (286, 77), (286, 78), (286, 79), (286, 80), (286, 81), (286, 82), (286, 83), (286, 84), (286, 85), (287, 85), (287, 86), (287, 87), (288, 87), (288, 88), (289, 88), (290, 88), (290, 89), (291, 89), (292, 89), (293, 89), (293, 90), (294, 90), (295, 90), (296, 90), (297, 90), (297, 91), (298, 91), (299, 91), (300, 91), (300, 92), (301, 92), (302, 92), (302, 93), (303, 93), (304, 93), (304, 94), (305, 94), (306, 94), (306, 95), (307, 95), (308, 95), (308, 96), (309, 96), (310, 96), (310, 97), (311, 97), (312, 97), (313, 97), (314, 97), (315, 97), (316, 97), (317, 97), (318, 97), (319, 97), (320, 97), (321, 97), (322, 97), (323, 97), (324, 97), (325, 97), (326, 97), (327, 97), (328, 97), (329, 97), (330, 97), (331, 97), (332, 97), (333, 97), (334, 97), (335, 97), (336, 97), (337, 97), (338, 97), (339, 97), (340, 97), (341, 97), (342, 97), (343, 97), (344, 97), (345, 97), (346, 97), (347, 97), (348, 97), (348, 98), (349, 98), (350, 98), (351, 98), (351, 99), (352, 99), (353, 99), (353, 100), (353, 101), (354, 101), (354, 102), (355, 102), (355, 103), (355, 104), (356, 104), (356, 105), (357, 105), (357, 106), (357, 107), (358, 107), (358, 108), (358, 109), (358, 110), (359, 110), (359, 111), (359, 112), (359, 113), (359, 114), (359, 115), (359, 116), (359, 117), (359, 118), (359, 119), (359, 120), (359, 121), (359, 122), (359, 123), (359, 124), (359, 125), (359, 126), (359, 127), (359, 128), (359, 129), (359, 130), (359, 131), (359, 132), (359, 133), (359, 134), (359, 135), (359, 136), (359, 137), (359, 138), (359, 139), (359, 140), (360, 140), (361, 140), (362, 140), (363, 140), (364, 140), (365, 140), (366, 140), (367, 140), (368, 140), (369, 140), (370, 140), (371, 140), (372, 140), (373, 140), (374, 140), (375, 140), (376, 140), (377, 140), (377, 139), (378, 139), (379, 139), (379, 138), (379, 137), (379, 136), (380, 136), (381, 136), (381, 135), (382, 135), (383, 135), (384, 135), (385, 135), (386, 135), (387, 135), (388, 135), (388, 134), (389, 134), (390, 134), (390, 133), (391, 133), (392, 133), (393, 133), (394, 133), (395, 133), (396, 133), (397, 133), (398, 133), (399, 133), (400, 133), (401, 133), (402, 133), (403, 133), (403, 132), (403, 131), (403, 130), (403, 129), (404, 129), (405, 129), (405, 128), (406, 128), (407, 128), (407, 127), (408, 127), (408, 126), (409, 126), (409, 125), (409, 124), (410, 124), (410, 123), (410, 122), (411, 122), (411, 121), (412, 121), (412, 120), (412, 119), (413, 119), (413, 118), (413, 117), (414, 117), (414, 116), (415, 116), (416, 116), (417, 116), (417, 115), (417, 114), (417, 113), (417, 112), (417, 111), (417, 110), (417, 109), (417, 108), (418, 108), (418, 107), (418, 106), (418, 105), (419, 105), (419, 104), (419, 103), (419, 102), (419, 101), (420, 101), (420, 100), (420, 99), (420, 98), (420, 97), (420, 96), (420, 95), (420, 94), (420, 93), (420, 92), (420, 91), (420, 90), (420, 89), (420, 88), (420, 87), (420, 86), (420, 85), (420, 84), (420, 83), (420, 82), (420, 81), (420, 80), (420, 79), (420, 78), (420, 77), (420, 76), (420, 75), (420, 74), (420, 73), (420, 72), (420, 71), ( ...

# %%
dist,nb_etats, path = algoDijkstra("brc101d.map", (279,1), (476,25))
@time algoDijkstra("brc101d.map", (279,1), (476,25))
println("Distance minimale : ", dist[476,25])
println("Activité : ", nb_etats)
println("Chemin : ", path)
# Out:
#   0.020167 seconds (822.82 k allocations: 26.359 MiB)
# Distance minimale : 457.0
# Activité : 18811
# Chemin : [(279, 1), (279, 2), (279, 3), (279, 4), (279, 5), (279, 6), (279, 7), (279, 8), (279, 9), (279, 10), (279, 11), (279, 12), (279, 13), (279, 14), (279, 15), (279, 16), (279, 17), (279, 18), (279, 19), (279, 20), (279, 21), (279, 22), (279, 23), (279, 24), (279, 25), (279, 26), (279, 27), (279, 28), (279, 29), (279, 30), (280, 30), (280, 31), (280, 32), (281, 32), (281, 33), (281, 34), (281, 35), (281, 36), (282, 36), (282, 37), (282, 38), (282, 39), (283, 39), (284, 39), (285, 39), (285, 40), (286, 40), (286, 41), (286, 42), (286, 43), (286, 44), (286, 45), (286, 46), (286, 47), (286, 48), (286, 49), (286, 50), (286, 51), (286, 52), (286, 53), (286, 54), (286, 55), (286, 56), (286, 57), (287, 57), (287, 58), (288, 58), (289, 58), (290, 58), (291, 58), (291, 59), (291, 60), (291, 61), (292, 61), (292, 62), (292, 63), (292, 64), (292, 65), (292, 66), (293, 66), (294, 66), (295, 66), (295, 67), (296, 67), (296, 68), (296, 69), (296, 70), (297, 70), (297, 71), (298, 71), (299, 71), (300, 71), (300, 72), (301, 72), (302, 72), (303, 72), (304, 72), (305, 72), (306, 72), (306, 73), (307, 73), (307, 74), (307, 75), (308, 75), (309, 75), (310, 75), (311, 75), (312, 75), (313, 75), (313, 76), (314, 76), (315, 76), (315, 77), (315, 78), (315, 79), (315, 80), (316, 80), (316, 81), (317, 81), (318, 81), (319, 81), (319, 82), (320, 82), (321, 82), (322, 82), (322, 83), (323, 83), (324, 83), (325, 83), (325, 84), (326, 84), (327, 84), (328, 84), (328, 85), (329, 85), (330, 85), (331, 85), (332, 85), (333, 85), (334, 85), (335, 85), (336, 85), (337, 85), (337, 86), (337, 87), (338, 87), (338, 88), (339, 88), (339, 89), (340, 89), (340, 90), (340, 91), (340, 92), (341, 92), (342, 92), (343, 92), (343, 93), (344, 93), (345, 93), (346, 93), (346, 94), (347, 94), (348, 94), (349, 94), (350, 94), (351, 94), (351, 95), (351, 96), (351, 97), (351, 98), (351, 99), (352, 99), (353, 99), (353, 100), (353, 101), (354, 101), (355, 101), (355, 102), (355, 103), (355, 104), (356, 104), (356, 105), (357, 105), (357, 106), (357, 107), (358, 107), (358, 108), (358, 109), (358, 110), (359, 110), (359, 111), (359, 112), (359, 113), (359, 114), (359, 115), (359, 116), (359, 117), (359, 118), (359, 119), (359, 120), (359, 121), (359, 122), (359, 123), (359, 124), (359, 125), (359, 126), (359, 127), (359, 128), (359, 129), (359, 130), (359, 131), (359, 132), (359, 133), (359, 134), (359, 135), (359, 136), (360, 136), (361, 136), (362, 136), (363, 136), (364, 136), (364, 137), (365, 137), (366, 137), (367, 137), (368, 137), (369, 137), (370, 137), (371, 137), (371, 138), (371, 139), (372, 139), (373, 139), (373, 140), (374, 140), (375, 140), (376, 140), (377, 140), (378, 140), (379, 140), (380, 140), (381, 140), (382, 140), (383, 140), (384, 140), (385, 140), (386, 140), (387, 140), (388, 140), (389, 140), (390, 140), (391, 140), (392, 140), (393, 140), (394, 140), (395, 140), (395, 139), (395, 138), (395, 137), (396, 137), (397, 137), (398, 137), (398, 136), (398, 135), (398, 134), (398, 133), (399, 133), (400, 133), (401, 133), (402, 133), (403, 133), (404, 133), (405, 133), (405, 132), (405, 131), (406, 131), (407, 131), (408, 131), (408, 130), (408, 129), (408, 128), (408, 127), (408, 126), (409, 126), (410, 126), (411, 126), (412, 126), (413, 126), (413, 125), (413, 124), (413, 123), (414, 123), (415, 123), (416, 123), (417, 123), (417, 122), (417, 121), (417, 120), (417, 119), (417, 118), (417, 117), (417, 116), (417, 115), (417, 114), (417, 113), (417, 112), (417, 111), (417, 110), (417, 109), (417, 108), (418, 108), (418, 107), (418, 106), (419, 106), (419, 105), (419, 104), (419, 103), (420, 103), (420, 102), (420, 101), (420, 100), (420, 99), (420, 98), (420, 97), (420, 96), (420, 95), (420, 94), (420, 93), (420, 92), (420, 91), (420, 90), (420, 89), (420, 88), (420, 87), (420, 86), (420, 85), (420, 84), (420, 83), (420, 82), (420, 81), (421, 81), (422, 81), (423, 81), (424, 81), (425, 81), (426, 81), (426, 80), (427, 80), (428, 80), (428, 79), ( ...

# %%
dist,nb_etats,path = algoGlouton("brc101d.map", (279,1), (476,25))
@time algoGlouton("brc101d.map", (279,1), (476,25))
println("Distance minimale : ", dist[476,25])
println("Activité : ", nb_etats)
println("Chemin : ", path)
# Out:
#   0.015360 seconds (304.02 k allocations: 13.583 MiB, 48.89% gc time)
# Distance minimale : 473.0
# Activité : 2736
# Chemin : [(279, 1), (279, 2), (279, 3), (279, 4), (279, 5), (279, 6), (279, 7), (279, 8), (279, 9), (279, 10), (279, 11), (279, 12), (279, 13), (279, 14), (279, 15), (279, 16), (279, 17), (279, 18), (279, 19), (279, 20), (279, 21), (279, 22), (279, 23), (279, 24), (279, 25), (280, 25), (281, 25), (282, 25), (283, 25), (284, 25), (285, 25), (286, 25), (287, 25), (288, 25), (289, 25), (290, 25), (291, 25), (292, 25), (293, 25), (294, 25), (295, 25), (295, 26), (296, 26), (296, 27), (296, 28), (297, 28), (297, 29), (298, 29), (298, 30), (299, 30), (299, 31), (299, 32), (300, 32), (300, 33), (301, 33), (301, 34), (301, 35), (302, 35), (302, 36), (303, 36), (303, 37), (304, 37), (304, 38), (304, 39), (305, 39), (305, 40), (306, 40), (306, 41), (306, 42), (307, 42), (307, 43), (308, 43), (308, 44), (309, 44), (309, 45), (309, 46), (310, 46), (310, 47), (311, 47), (311, 48), (311, 49), (311, 50), (311, 51), (311, 52), (311, 53), (311, 54), (311, 55), (311, 56), (311, 57), (311, 58), (311, 59), (311, 60), (311, 61), (311, 62), (311, 63), (311, 64), (311, 65), (311, 66), (311, 67), (311, 68), (312, 68), (312, 69), (312, 70), (313, 70), (313, 71), (313, 72), (313, 73), (314, 73), (314, 74), (314, 75), (314, 76), (315, 76), (315, 77), (315, 78), (316, 78), (316, 79), (317, 79), (317, 80), (318, 80), (319, 80), (320, 80), (320, 81), (321, 81), (321, 82), (322, 82), (323, 82), (323, 83), (324, 83), (325, 83), (326, 83), (326, 84), (327, 84), (328, 84), (329, 84), (329, 85), (330, 85), (331, 85), (332, 85), (333, 85), (333, 84), (334, 84), (335, 84), (336, 84), (337, 84), (338, 84), (339, 84), (340, 84), (340, 83), (341, 83), (342, 83), (342, 82), (343, 82), (344, 82), (344, 81), (345, 81), (346, 81), (347, 81), (348, 81), (349, 81), (349, 82), (350, 82), (350, 83), (351, 83), (351, 84), (352, 84), (353, 84), (353, 85), (354, 85), (354, 86), (355, 86), (355, 87), (356, 87), (356, 88), (357, 88), (357, 89), (358, 89), (359, 89), (359, 90), (360, 90), (360, 91), (361, 91), (361, 92), (362, 92), (362, 93), (363, 93), (363, 94), (364, 94), (364, 95), (365, 95), (366, 95), (366, 96), (366, 97), (366, 98), (366, 99), (367, 99), (367, 100), (367, 101), (367, 102), (367, 103), (367, 104), (367, 105), (367, 106), (367, 107), (367, 108), (367, 109), (367, 110), (367, 111), (367, 112), (367, 113), (367, 114), (367, 115), (367, 116), (367, 117), (367, 118), (367, 119), (367, 120), (367, 121), (367, 122), (367, 123), (368, 123), (368, 124), (368, 125), (368, 126), (368, 127), (368, 128), (368, 129), (368, 130), (368, 131), (369, 131), (369, 132), (370, 132), (370, 133), (371, 133), (372, 133), (372, 134), (372, 135), (372, 136), (372, 137), (372, 138), (372, 139), (373, 139), (373, 140), (374, 140), (375, 140), (376, 140), (377, 140), (377, 139), (378, 139), (379, 139), (379, 138), (379, 137), (379, 136), (380, 136), (381, 136), (381, 135), (382, 135), (383, 135), (384, 135), (385, 135), (386, 135), (387, 135), (388, 135), (388, 134), (389, 134), (390, 134), (390, 133), (391, 133), (392, 133), (393, 133), (394, 133), (395, 133), (395, 132), (396, 132), (397, 132), (398, 132), (399, 132), (400, 132), (400, 133), (401, 133), (402, 133), (403, 133), (403, 132), (403, 131), (403, 130), (403, 129), (404, 129), (405, 129), (405, 128), (406, 128), (407, 128), (407, 127), (408, 127), (408, 126), (409, 126), (409, 125), (409, 124), (410, 124), (410, 123), (410, 122), (411, 122), (411, 121), (412, 121), (412, 120), (412, 119), (413, 119), (413, 118), (413, 117), (414, 117), (414, 116), (415, 116), (416, 116), (417, 116), (417, 115), (417, 114), (417, 113), (417, 112), (417, 111), (417, 110), (417, 109), (417, 108), (418, 108), (418, 107), (418, 106), (418, 105), (419, 105), (419, 104), (419, 103), (419, 102), (419, 101), (420, 101), (420, 100), (420, 99), (420, 98), (420, 97), (420, 96), (420, 95), (420, 94), (420, 93), (420, 92), (420, 91), (420, 90), (420, 89), (420, 88), (420, 87), (420, 86), (420, 85), (420, 84), (420, 83), (420, 82), (420, 81), (420, 80), (4 ...

# %%
dist,nb_etats,path = algoAstar("brc101d.map", (279,1), (476,25))
@time algoAstar("brc101d.map", (279,1), (476,25))
println("Distance minimale : ", dist[476,25])
println("Activité : ", nb_etats)
println("Chemin : ", path)
# Out:
#   0.012272 seconds (409.60 k allocations: 16.202 MiB, 23.48% gc time)
# Distance minimale : 457.0
# Activité : 6040
# Chemin : [(279, 1), (279, 2), (279, 3), (280, 3), (281, 3), (281, 4), (281, 5), (281, 6), (282, 6), (282, 7), (282, 8), (283, 8), (284, 8), (285, 8), (285, 9), (286, 9), (286, 10), (287, 10), (287, 11), (288, 11), (289, 11), (290, 11), (290, 12), (291, 12), (292, 12), (292, 13), (293, 13), (293, 14), (294, 14), (294, 15), (294, 16), (295, 16), (295, 17), (295, 18), (295, 19), (295, 20), (295, 21), (295, 22), (295, 23), (295, 24), (295, 25), (295, 26), (296, 26), (296, 27), (296, 28), (297, 28), (297, 29), (298, 29), (298, 30), (299, 30), (299, 31), (299, 32), (300, 32), (300, 33), (301, 33), (301, 34), (301, 35), (302, 35), (302, 36), (303, 36), (303, 37), (304, 37), (304, 38), (304, 39), (305, 39), (305, 40), (306, 40), (306, 41), (306, 42), (307, 42), (307, 43), (308, 43), (308, 44), (309, 44), (309, 45), (309, 46), (310, 46), (310, 47), (311, 47), (311, 48), (311, 49), (311, 50), (311, 51), (311, 52), (311, 53), (311, 54), (311, 55), (311, 56), (311, 57), (311, 58), (311, 59), (311, 60), (311, 61), (311, 62), (311, 63), (311, 64), (311, 65), (311, 66), (311, 67), (311, 68), (312, 68), (312, 69), (312, 70), (313, 70), (313, 71), (313, 72), (313, 73), (314, 73), (314, 74), (314, 75), (314, 76), (315, 76), (315, 77), (315, 78), (316, 78), (316, 79), (317, 79), (317, 80), (318, 80), (319, 80), (320, 80), (320, 81), (321, 81), (321, 82), (322, 82), (323, 82), (323, 83), (324, 83), (325, 83), (326, 83), (326, 84), (327, 84), (328, 84), (329, 84), (329, 85), (330, 85), (331, 85), (332, 85), (333, 85), (334, 85), (335, 85), (336, 85), (337, 85), (338, 85), (339, 85), (340, 85), (341, 85), (342, 85), (343, 85), (344, 85), (345, 85), (346, 85), (347, 85), (348, 85), (349, 85), (350, 85), (351, 85), (352, 85), (353, 85), (354, 85), (354, 86), (355, 86), (355, 87), (356, 87), (356, 88), (357, 88), (357, 89), (358, 89), (359, 89), (359, 90), (360, 90), (360, 91), (361, 91), (361, 92), (362, 92), (362, 93), (363, 93), (363, 94), (364, 94), (364, 95), (365, 95), (366, 95), (366, 96), (366, 97), (366, 98), (366, 99), (367, 99), (367, 100), (367, 101), (367, 102), (367, 103), (367, 104), (367, 105), (367, 106), (367, 107), (367, 108), (367, 109), (367, 110), (367, 111), (367, 112), (367, 113), (367, 114), (367, 115), (367, 116), (367, 117), (367, 118), (367, 119), (367, 120), (367, 121), (367, 122), (367, 123), (368, 123), (368, 124), (368, 125), (368, 126), (368, 127), (368, 128), (368, 129), (368, 130), (368, 131), (369, 131), (369, 132), (370, 132), (370, 133), (371, 133), (372, 133), (372, 134), (372, 135), (372, 136), (372, 137), (372, 138), (372, 139), (373, 139), (373, 140), (374, 140), (375, 140), (376, 140), (377, 140), (378, 140), (379, 140), (380, 140), (381, 140), (382, 140), (382, 139), (382, 138), (383, 138), (384, 138), (385, 138), (386, 138), (387, 138), (388, 138), (389, 138), (390, 138), (391, 138), (392, 138), (393, 138), (394, 138), (394, 137), (395, 137), (395, 136), (395, 135), (396, 135), (397, 135), (398, 135), (398, 134), (399, 134), (400, 134), (401, 134), (401, 133), (402, 133), (403, 133), (404, 133), (405, 133), (405, 132), (406, 132), (406, 131), (407, 131), (407, 130), (408, 130), (408, 129), (408, 128), (409, 128), (409, 127), (410, 127), (410, 126), (411, 126), (411, 125), (411, 124), (411, 123), (412, 123), (412, 122), (412, 121), (413, 121), (413, 120), (414, 120), (415, 120), (415, 119), (415, 118), (416, 118), (416, 117), (416, 116), (417, 116), (417, 115), (418, 115), (419, 115), (420, 115), (421, 115), (421, 114), (421, 113), (422, 113), (422, 112), (422, 111), (422, 110), (422, 109), (422, 108), (422, 107), (422, 106), (422, 105), (422, 104), (422, 103), (422, 102), (422, 101), (422, 100), (423, 100), (423, 99), (423, 98), (424, 98), (424, 97), (424, 96), (425, 96), (425, 95), (426, 95), (426, 94), (426, 93), (426, 92), (426, 91), (427, 91), (427, 90), (427, 89), (427, 88), (427, 87), (427, 86), (427, 85), (427, 84), (427, 83), (427, 82), (427, 81), (427, 80), (427, 79), (427, 78), (427, 77), (427, 76 ...
